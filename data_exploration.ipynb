# %%
import numpy as np

# %%
data_path = "data/tiny_nerf_data.npz"
data = np.load(data_path)

# %%
type(data)
# Out:
# NpzFile 'data/tiny_nerf_data.npz' with keys: images, poses, focal

# %%
images = data["images"]
images.shape
# Out:
# (106, 100, 100, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(images[100])
